# %% [markdown]
# ### Data Importing and Preprocessing

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('C:/Users/Personal/House_Price.csv', header=0)

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   waterbody  rainfall bus_ter     parks
# 0     River        23     YES  0.049347
# ...

# %%
df.shape
# Out:
# (506, 19)

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    3.613524   41.136779    0.554695    6.284634   68.574901
# std      9.182176    8.601545    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006320   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.082045   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.256510   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    3.677083   48.100000    0.624000    6.623500   94.075000
# max     50.000000   88.976200   57.740000    0.871000    8.780000  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.971996    3.628775    3.960672    3.618972   21.544466   12.653063
# ...

# %%
sns.jointplot(x='n_hot_rooms', y='price', data=df)

# %%
sns.jointplot(x='rainfall', y='price', data=df)

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   waterbody  rainfall bus_ter     parks
# 0     River        23     YES  0.049347
# ...

# %%
sns.countplot(x='airport', data=df)
# Out:
# <AxesSubplot:xlabel='airport', ylabel='count'>

# %%
sns.countplot(x='waterbody', data=df)
# Out:
# <AxesSubplot:xlabel='waterbody', ylabel='count'>

# %%
sns.countplot(x='bus_ter', data=df)
# Out:
# <AxesSubplot:xlabel='bus_ter', ylabel='count'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   498 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    506 non-null    object
#  16  rainfall     506 non-null    int64
#  17  bus_ter      506 non-null    object
# ...

# %%
upper_limit = np.percentile(df.n_hot_rooms, [99])[0]

# %%
df[(df.n_hot_rooms)>upper_limit]
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 2     34.7     0.02729       37.07    0.4690     7.185  61.1   5.03   4.86
# 166   50.0     2.01019       49.58    0.6050     7.929  96.2   2.11   1.91
# 204   50.0     0.02009       32.68    0.4161     8.034  31.9   5.41   4.80
# 267   50.0     0.57834       33.97    0.5750     8.297  67.0   2.60   2.13
# 369   50.0     5.66998       48.10    0.6310     6.683  96.8   1.55   1.28
# 423   13.4     7.05042       48.10    0.6140     6.103  85.1   2.08   1.80
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 2     5.01   4.97      22.2       4.03      NO       7.394       101.12
# 166   2.31   1.86      25.3       3.70     YES       8.300        15.40
# 204   5.28   4.99      25.3       2.88     YES       8.900        15.40
# 267   2.43   2.52      27.0       7.44     YES       8.000        15.40
# 369   1.65   0.94      19.8       3.73     YES       6.700        15.40
# ...

# %%
df[(df.n_hot_rooms>(3*upper_limit))] = 3*upper_limit

# %%
low_lim_rainfall = np.percentile(df.rainfall,[1])[0]

# %%
df[(df.rainfall<(low_lim_rainfall))]
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 213   28.1     0.14052       40.59     0.489     6.375  32.3   4.11   3.92
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 213   4.18   3.57      21.4       9.38     YES       7.562      10.2248
#
#     waterbody  rainfall bus_ter     parks
# 213      None       3.0     YES  0.044019

# %%
df[(df.rainfall<(0.3*low_lim_rainfall))] = 0.3*low_lim_rainfall

# %%
upper_lim_crimerate = np.percentile(df.crime_rate,[99])[0]

# %%
df[(df.crime_rate)>upper_lim_crimerate]
# Out:
#         price  crime_rate  resid_area  air_qual  room_num        age  \
# 2    46.19856    46.19856    46.19856  46.19856  46.19856   46.19856
# 380  10.40000    88.97620    48.10000   0.67100   6.96800   91.90000
# 405   5.00000    67.92080    48.10000   0.69300   5.68300  100.00000
# 410  15.00000    51.13580    48.10000   0.59700   5.75700  100.00000
# 418   8.80000    73.53410    48.10000   0.67900   5.95700  100.00000
# 423  46.19856    46.19856    46.19856  46.19856  46.19856   46.19856
#
#         dist1     dist2     dist3     dist4  teachers  poor_prop   airport  \
# 2    46.19856  46.19856  46.19856  46.19856  46.19856   46.19856  46.19856
# 380   1.66000   1.14000   1.69000   1.18000  19.80000   17.21000       YES
# 405   1.53000   1.19000   1.44000   1.54000  19.80000   22.98000       YES
# 410   1.69000   1.32000   1.58000   1.06000  19.80000   10.11000        NO
# 418   1.96000   1.69000   1.85000   1.70000  19.80000   20.62000        NO
# ...

# %%
df[(df.crime_rate)>(3*upper_lim_crimerate)] = 3*upper_lim_crimerate

# %%
df.crime_rate
# Out:
# 0       0.00632
# 1       0.02731
# 2      46.19856
# 3       0.03237
# 4       0.06905
#          ...
# 501     0.06263
# 502     0.04527
# 503     0.06076
# 504     0.10959
# 505     0.04741
# Name: crime_rate, Length: 506, dtype: float64

# %%
df.head()
# Out:
#       price  crime_rate  resid_area  air_qual  room_num       age     dist1  \
# 0  24.00000     0.00632    32.31000   0.53800   6.57500  65.20000   4.35000
# 1  21.60000     0.02731    37.07000   0.46900   6.42100  78.90000   4.99000
# 2  46.19856    46.19856    46.19856  46.19856  46.19856  46.19856  46.19856
# 3  33.40000     0.03237    32.18000   0.45800   6.99800  45.80000   6.21000
# 4  36.20000     0.06905    32.18000   0.45800   7.14700  54.20000   6.16000
#
#       dist2     dist3     dist4  teachers  poor_prop   airport  n_hos_beds  \
# 0   3.81000   4.18000   4.01000  24.70000    4.98000       YES     5.48000
# 1   4.70000   5.12000   5.06000  22.20000    9.14000        NO     7.33200
# 2  46.19856  46.19856  46.19856  46.19856   46.19856  46.19856    46.19856
# 3   5.93000   6.16000   5.96000  21.30000    2.94000       YES     9.26800
# 4   5.86000   6.37000   5.86000  21.30000    5.33000        NO     8.82400
#
#    n_hot_rooms waterbody  rainfall   bus_ter      parks
# ...

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.572722    3.793719   41.082702    0.746049    6.440235   68.416595
# std      9.303248    9.004149    7.034086    2.878605    2.603320   28.263278
# min      5.000000    0.006320    6.000000    0.385000    3.561000    2.900000
# 25%     17.025000    0.082268   35.145000    0.449000    5.885500   45.025000
# 50%     21.200000    0.262660   39.690000    0.538000    6.208500   77.150000
# 75%     25.000000    3.695990   48.100000    0.629250    6.628000   94.075000
# max     50.000000   88.976200   57.740000   46.198560   46.198560  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     4.144283    3.802326    4.132346    3.792860   21.613631   12.774994
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   498 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    506 non-null    object
#  16  rainfall     506 non-null    float64
#  17  bus_ter      506 non-null    object
# ...

# %%
df.n_hos_beds = df.n_hos_beds.fillna(df.n_hos_beds.mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   506 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    506 non-null    object
#  16  rainfall     506 non-null    float64
#  17  bus_ter      506 non-null    object
# ...

# %%
sns.jointplot(x='crime_rate', y='price', data = df)

# %%
df.crime_rate = np.log(1+df.crime_rate)

# %%
sns.jointplot(x='crime_rate', y='price', data = df)

# %%
df['avg_dist'] = (df.dist1+df.dist2+df.dist3+df.dist4)/4

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.572722    0.828063   41.082702    0.746049    6.440235   68.416595
# std      9.303248    1.039027    7.034086    2.878605    2.603320   28.263278
# min      5.000000    0.006300    6.000000    0.385000    3.561000    2.900000
# 25%     17.025000    0.079058   35.145000    0.449000    5.885500   45.025000
# 50%     21.200000    0.233220   39.690000    0.538000    6.208500   77.150000
# 75%     25.000000    1.546709   48.100000    0.629250    6.628000   94.075000
# max     50.000000    4.499545   57.740000   46.198560   46.198560  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     4.144283    3.802326    4.132346    3.792860   21.613631   12.774994
# ...

# %%
del df['dist1']

# %%
del df['dist2']

# %%
del df['dist3']

# %%
del df['dist4']

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.572722    0.828063   41.082702    0.746049    6.440235   68.416595
# std      9.303248    1.039027    7.034086    2.878605    2.603320   28.263278
# min      5.000000    0.006300    6.000000    0.385000    3.561000    2.900000
# 25%     17.025000    0.079058   35.145000    0.449000    5.885500   45.025000
# 50%     21.200000    0.233220   39.690000    0.538000    6.208500   77.150000
# 75%     25.000000    1.546709   48.100000    0.629250    6.628000   94.075000
# max     50.000000    4.499545   57.740000   46.198560   46.198560  100.000000
#
#          teachers   poor_prop  n_hos_beds  n_hot_rooms    rainfall  \
# count  506.000000  506.000000  506.000000   506.000000  506.000000
# mean    21.613631   12.774994    8.050717    12.855700   39.237939
# ...

# %%
del df['bus_ter']

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.572722    0.828063   41.082702    0.746049    6.440235   68.416595
# std      9.303248    1.039027    7.034086    2.878605    2.603320   28.263278
# min      5.000000    0.006300    6.000000    0.385000    3.561000    2.900000
# 25%     17.025000    0.079058   35.145000    0.449000    5.885500   45.025000
# 50%     21.200000    0.233220   39.690000    0.538000    6.208500   77.150000
# 75%     25.000000    1.546709   48.100000    0.629250    6.628000   94.075000
# max     50.000000    4.499545   57.740000   46.198560   46.198560  100.000000
#
#          teachers   poor_prop  n_hos_beds  n_hot_rooms    rainfall  \
# count  506.000000  506.000000  506.000000   506.000000  506.000000
# mean    21.613631   12.774994    8.050717    12.855700   39.237939
# ...

# %%
df.head()
# Out:
#       price  crime_rate  resid_area  air_qual  room_num       age  teachers  \
# 0  24.00000    0.006300    32.31000   0.53800   6.57500  65.20000  24.70000
# 1  21.60000    0.026944    37.07000   0.46900   6.42100  78.90000  22.20000
# 2  46.19856    3.854363    46.19856  46.19856  46.19856  46.19856  46.19856
# 3  33.40000    0.031857    32.18000   0.45800   6.99800  45.80000  21.30000
# 4  36.20000    0.066770    32.18000   0.45800   7.14700  54.20000  21.30000
#
#    poor_prop   airport  n_hos_beds  n_hot_rooms waterbody  rainfall  \
# 0    4.98000       YES     5.48000     11.19200     River  23.00000
# 1    9.14000        NO     7.33200     12.17280      Lake  42.00000
# 2   46.19856  46.19856    46.19856     46.19856  46.19856  46.19856
# 3    2.94000       YES     9.26800     11.26720      Lake  45.00000
# 4    5.33000        NO     8.82400     11.28960      Lake  55.00000
#
#        parks  avg_dist
# 0   0.049347   4.08750
# 1   0.046146   4.96750
# 2  46.198560  46.19856
# ...

# %%
df = pd.get_dummies(df)

# %%
df.head()
# Out:
#       price  crime_rate  resid_area  air_qual  room_num       age  teachers  \
# 0  24.00000    0.006300    32.31000   0.53800   6.57500  65.20000  24.70000
# 1  21.60000    0.026944    37.07000   0.46900   6.42100  78.90000  22.20000
# 2  46.19856    3.854363    46.19856  46.19856  46.19856  46.19856  46.19856
# 3  33.40000    0.031857    32.18000   0.45800   6.99800  45.80000  21.30000
# 4  36.20000    0.066770    32.18000   0.45800   7.14700  54.20000  21.30000
#
#    poor_prop  n_hos_beds  n_hot_rooms  ...  airport_6.0  airport_46.19856  \
# 0    4.98000     5.48000     11.19200  ...            0                 0
# 1    9.14000     7.33200     12.17280  ...            0                 0
# 2   46.19856    46.19856     46.19856  ...            0                 1
# 3    2.94000     9.26800     11.26720  ...            0                 0
# 4    5.33000     8.82400     11.28960  ...            0                 0
#
# ...

# %%
# since we need to have only one less the number of categories as our dummy variable.
# so, deleting the airport no and waterbody none columns as they are redundant.

# %%
del df['airport_NO']

# %%
del df['waterbody_None']

# %%
df.head()
# Out:
#       price  crime_rate  resid_area  air_qual  room_num       age  teachers  \
# 0  24.00000    0.006300    32.31000   0.53800   6.57500  65.20000  24.70000
# 1  21.60000    0.026944    37.07000   0.46900   6.42100  78.90000  22.20000
# 2  46.19856    3.854363    46.19856  46.19856  46.19856  46.19856  46.19856
# 3  33.40000    0.031857    32.18000   0.45800   6.99800  45.80000  21.30000
# 4  36.20000    0.066770    32.18000   0.45800   7.14700  54.20000  21.30000
#
#    poor_prop  n_hos_beds  n_hot_rooms  ...      parks  avg_dist  airport_6.0  \
# 0    4.98000     5.48000     11.19200  ...   0.049347   4.08750            0
# 1    9.14000     7.33200     12.17280  ...   0.046146   4.96750            0
# 2   46.19856    46.19856     46.19856  ...  46.198560  46.19856            0
# 3    2.94000     9.26800     11.26720  ...   0.047151   6.06500            0
# 4    5.33000     8.82400     11.28960  ...   0.039474   6.06250            0
#
# ...

# %%
df.corr()
# Out:
#                              price  crime_rate  resid_area  air_qual  \
# price                     1.000000   -0.389582   -0.484754 -0.429300
# crime_rate               -0.389582    1.000000    0.406583  0.420972
# resid_area               -0.484754    0.406583    1.000000  0.763651
# air_qual                 -0.429300    0.420972    0.763651  1.000000
# room_num                  0.696304   -0.219247   -0.391676 -0.302188
# age                      -0.377999    0.352734    0.644779  0.731470
# dist1                     0.251355   -0.380050   -0.706481 -0.768589
# dist2                     0.249459   -0.379813   -0.707956 -0.769724
# dist3                     0.246650   -0.380069   -0.707566 -0.769157
# dist4                     0.248200   -0.376462   -0.705819 -0.764873
# teachers                  0.505655   -0.289946   -0.383248 -0.188933
# poor_prop                -0.740836    0.455621    0.603800  0.590879
# n_hos_beds                0.109646    0.017502    0.005827 -0.049954
# ...

# %%
# find the correlation variables for which the values are higher than 0.8 or higher than -0.8
# check which of the two variables has a higher correlation value with the dependent variable 
# delete the variable with lower value as that is not required for our analysis.

# %%
del df['parks']

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop  n_hos_beds  n_hot_rooms  rainfall  \
# 0   4.18   4.01      24.7       4.98       5.480      11.1920        23
# 1   5.12   5.06      22.2       9.14       7.332      12.1728        42
# 2   5.01   4.97      22.2       4.03       7.394     101.1200        38
# 3   6.16   5.96      21.3       2.94       9.268      11.2672        45
# 4   6.37   5.86      21.3       5.33       8.824      11.2896        55
#
#    airport_YES  waterbody_Lake  waterbody_Lake and River  waterbody_River  \
# ...

# %%
df.corr()
# Out:
#                              price  crime_rate  resid_area  air_qual  \
# price                     1.000000   -0.389582   -0.484754 -0.429300
# crime_rate               -0.389582    1.000000    0.406583  0.420972
# resid_area               -0.484754    0.406583    1.000000  0.763651
# air_qual                 -0.429300    0.420972    0.763651  1.000000
# room_num                  0.696304   -0.219247   -0.391676 -0.302188
# age                      -0.377999    0.352734    0.644779  0.731470
# dist1                     0.251355   -0.380050   -0.706481 -0.768589
# dist2                     0.249459   -0.379813   -0.707956 -0.769724
# dist3                     0.246650   -0.380069   -0.707566 -0.769157
# dist4                     0.248200   -0.376462   -0.705819 -0.764873
# teachers                  0.505655   -0.289946   -0.383248 -0.188933
# poor_prop                -0.740836    0.455621    0.603800  0.590879
# n_hos_beds                0.109646    0.017502    0.005827 -0.049954
# ...

# %%
##Simple Linear Regression model.

# %%
import statsmodels.api as sn

# %%
X=sn.add_constant(df['room_num'])

# %%
lm = sn.OLS(df['price'], X).fit()

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.485
# Model:                            OLS   Adj. R-squared:                  0.484
# Method:                 Least Squares   F-statistic:                     474.3
# Date:                Tue, 31 May 2022   Prob (F-statistic):           1.31e-74
# Time:                        13:00:56   Log-Likelihood:                -1671.6
# No. Observations:                 506   AIC:                             3347.
# Df Residuals:                     504   BIC:                             3356.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -34.6592      2.642    -13.118      0.000     -39.850     -29.468
# ...

# %%
# SKLEARN method for simple linear regression model using one variable

# %%
from sklearn.linear_model import LinearRegression

# %%
y = df['price']

# %%
x = df[['room_num']]

# %%
lm2 = LinearRegression()

# %%
lm2.fit(x,y)
# Out:
# LinearRegression()

# %%
print(lm2.intercept_, lm2.coef_)
# Out:
# -34.65924312309721 [9.09966966]

# %%
lm2.predict(x)
# Out:
# array([25.17108491, 23.76973578, 30.72188341, 29.02024518, 30.37609596,
#        23.85163281, 20.04797089, 21.50391804, 16.58099675, 19.97517353,
#        23.36935032, 20.02067188, 18.92871152, 19.4746917 , 20.81234314,
#        18.42822969, 19.34729633, 19.84777816, 14.98855456, 17.45456504,
#        16.0259169 , 19.62028642, 21.23092795, 18.23713663, 19.24719996,
#        16.28980732, 18.23713663, 20.36645933, 24.44311134, 26.07195221,
#        17.32716966, 20.59395107, 19.48379137, 17.21797363, 20.81234314,
#        19.32909699, 18.49192738, 18.57382441, 19.62938609, 25.3530783 ,
#        29.25683659, 26.9455205 , 21.47661903, 21.85880515, 20.56665206,
#        17.0450799 , 17.99144555, 20.21176495, 14.46987339, 16.31710633,
#        19.60208708, 20.98523687, 24.58870605, 19.92057552, 18.91961185,
#        31.30426226, 23.42394834, 27.3641053 , 21.25822696, 19.27449897,
#        17.58196041, 19.62938609, 24.08822422, 26.87272314, 29.98481016,
# ...

# %%
help(sns.jointplot)
# Out:
# Help on function jointplot in module seaborn.axisgrid:
#
# jointplot(*, x=None, y=None, data=None, kind='scatter', color=None, height=6, ratio=5, space=0.2, dropna=False, xlim=None, ylim=None, marginal_ticks=False, joint_kws=None, marginal_kws=None, hue=None, palette=None, hue_order=None, hue_norm=None, **kwargs)
#     Draw a plot of two variables with bivariate and univariate graphs.
#
#     This function provides a convenient interface to the :class:`JointGrid`
#     class, with several canned plot kinds. This is intended to be a fairly
#     lightweight wrapper; if you need more flexibility, you should use
#     :class:`JointGrid` directly.
#
#     Parameters
#     ----------
#     x, y : vectors or keys in ``data``
#         Variables that specify positions on the x and y axes.
#     data : :class:`pandas.DataFrame`, :class:`numpy.ndarray`, mapping, or sequence
#         Input data structure. Either a long-form collection of vectors that can be
# ...

# %%
sns.jointplot(x=df['room_num'], y=df['price'], data=df, kind="reg")

# %%
xmulti = df.drop('price',axis=1)

# %%
ymulti = df['price']

# %%
xmulticonst = sn.add_constant(xmulti)
# Out:
# E:\Python\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
lmmulti = sn.OLS(ymulti,xmulticonst).fit()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8916/2004573214.py in <module>
# ----> 1 lmmulti = sn.OLS(ymulti,xmulticonst).fit()
#
# E:\Python\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     870     def __init__(self, endog, exog=None, missing='none', hasconst=None,
#     871                  **kwargs):
# --> 872         super(OLS, self).__init__(endog, exog, missing=missing,
#     873                                   hasconst=hasconst, **kwargs)
#     874         if "weights" in self._init_keys:
#
# E:\Python\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     701         else:
#     702             weights = weights.squeeze()
# ...

# %%
lmmulti.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8916/4229975016.py in <module>
# ----> 1 lmmulti.summary()
#
# NameError: name 'lmmulti' is not defined

# %%
#multiple linear regression using sklearn library

# %%
from sklearn.linear_model import LinearRegression

# %%
yskl = df['price']

# %%
Xskl = df.drop('price', axis=1)

# %%
lmskl = LinearRegression()

# %%
lmskl.fit(X_train, y_train)
#print(lm_skl.intercept_)
#print(lm_skl.coef_)
# Out:
# LinearRegression()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(Xskl, yskl, test_size = 0.2, random_state = 0)

# %%
from sklearn.metrics import r2_score

# %%
y_pred = lmskl.predict(X_test)
score = r2_score(y_test, y_pred)

# %%
print(score)
# Out:
# -12.408789347599164

# %%
print(y_pred)
# Out:
# [ 27.81338463  23.06566124  26.35340096  12.7192037   23.95960949
#   20.68955772  19.51231605  20.75622264  18.1500947   23.09725147
#   13.87867843  18.39327043  16.90440643   4.60327303  39.00507932
#   33.06848889  20.27037651  35.98494657  32.09923687  22.96118501
#   26.22518565  25.82356759  21.32120836  28.98139783  21.62139287
#    9.86329927  18.16469894  19.6966646   37.4114128   23.33694262
#   18.60893159  16.8532818   20.08918549  23.01929208  30.83690475
#   17.50181067  10.9417135   22.80724018  19.38326409  15.12487251
#   28.03242466  22.0183264   24.65195236  13.15020047  27.44975104
#   25.7148539   21.28051811  21.4259937    9.96612511  25.82434953
#   22.04290825  17.87342654  24.02104523  32.91675396  14.04070882
#   22.13760559  21.19747665  17.51567406  20.59205987  19.39024443
#   19.06911574  21.6636999   33.21041672  31.94539714  15.49338183
#   33.45218525  17.45609328  19.45545368  21.09867962  24.01792123
# ...

# %%
sns.jointplot(x=X_test, y=y_pred, data=df, kind="reg")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11384/2476767632.py in <module>
# ----> 1 sns.jointplot(x=X_test, y=y_pred, data=df, kind="reg")
#
# E:\Python\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# E:\Python\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, color, height, ratio, space, dropna, xlim, ylim, marginal_ticks, joint_kws, marginal_kws, hue, palette, hue_order, hue_norm, **kwargs)
#    2228
#    2229     # Initialize the JointGrid object
# -> 2230     grid = JointGrid(
#    2231         data=data, x=x, y=y, hue=hue,
#    2232         palette=palette, hue_order=hue_order, hue_norm=hue_norm,
#
# ...
